# %% [raw]
# Intel_Image_Classification

# %% [raw]
# IMPORT IMPORTANT LIBRARIES

# %%
# Important imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from PIL import Image
from keras.models import Sequential
#from keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import BatchNormalization

from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, LeakyReLU
from sklearn.model_selection import train_test_split

# %%
# Listing directory
# !ls "Intel Image Dataset"
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Plotting 25 images to check dataset
plt.figure(figsize=(11,11))
path = "Intel Image Dataset/mountain"
for i in range(1,26):
    plt.subplot(5,5,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.title('mountain')
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %%
# Setting root directory path and creating empty list
dir = "Intel Image Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = Image.open(image_path)
    image = image.resize((150,150)) # All images does not have same dimension
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# 0
# glacier      553
# mountain     525
# sea          510
# street       501
# forest       474
# buildings    437
# Name: count, dtype: int64

# %%
# Checking x data shape
np.array(image_list).shape
# Out:
# (3000, 150, 150, 3)

# %%
# Checking y data shape
label_list = np.array(label_list)
label_list.shape
# Out:
# (3000,)

# %%
# Splitting dataset into test and train
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 150,150,3)
x_test = x_test.reshape( -1, 150,150,3)

# %%
# Binarizing labels
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %%
# Creating model architecture
model = Sequential([
        Conv2D(16, kernel_size = (3,3), input_shape = (150,150,3)),
        BatchNormalization(),
        LeakyReLU(),
          
        Conv2D(32, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        MaxPooling2D(5,5),
        
        Conv2D(64, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        
        Conv2D(128, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        MaxPooling2D(5,5),

        Flatten(),
        Dense(64),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(),
        
        Dense(32),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(),
    
        Dense(16),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(1),
    
        Dense(6, activation = 'softmax')    
        ])
model.summary()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 148, 148, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 148, 148, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 146, 146, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 146, 146, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 146, 146, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 29, 29, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 27, 27, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 27, 27, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 27, 27, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 25, 25, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 25, 25, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 25, 25, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3200)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       204,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           102 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 306,422 (1.17 MB)
#  Trainable params: 305,718 (1.17 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %%
# Training the model
epochs = 70
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 437s 14s/step - accuracy: 0.3275 - loss: 1.7765 - val_accuracy: 0.2542 - val_loss: 1.7945
# Epoch 2/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.5343 - loss: 1.2099 - val_accuracy: 0.1771 - val_loss: 1.8806
# Epoch 3/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.6112 - loss: 1.0348 - val_accuracy: 0.1771 - val_loss: 1.9916
# Epoch 4/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.6770 - loss: 0.9298 - val_accuracy: 0.1771 - val_loss: 2.0142
# Epoch 5/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.6937 - loss: 0.8637 - val_accuracy: 0.1771 - val_loss: 2.2589
# Epoch 6/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 64s 4s/step - accuracy: 0.7423 - loss: 0.7607 - val_accuracy: 0.1771 - val_loss: 2.4054
# Epoch 7/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 64s 4s/step - accuracy: 0.7794 - loss: 0.6881 - val_accuracy: 0.1771 - val_loss: 2.1277
# Epoch 8/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - accuracy: 0.8052 - loss: 0.6254 - val_accuracy: 0.1771 - val_loss: 2.3633
# Epoch 9/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.8363 - loss: 0.5750 - val_accuracy: 0.1771 - val_loss: 2.4511
# Epoch 10/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 59s 4s/step - accuracy: 0.8435 - loss: 0.5168 - val_accuracy: 0.1771 - val_loss: 2.4051
# Epoch 11/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 70s 5s/step - accuracy: 0.8880 - loss: 0.4440 - val_accuracy: 0.1771 - val_loss: 2.5943
# Epoch 12/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 71s 5s/step - accuracy: 0.8751 - loss: 0.4394 - val_accuracy: 0.1771 - val_loss: 2.8435
# Epoch 13/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 68s 5s/step - accuracy: 0.9107 - loss: 0.3789 - val_accuracy: 0.1771 - val_loss: 2.9095
# Epoch 14/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.9193 - loss: 0.3365 - val_accuracy: 0.1771 - val_loss: 2.3549
# Epoch 15/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 75s 5s/step - accuracy: 0.9407 - loss: 0.2995 - val_accuracy: 0.1771 - val_loss: 2.6056
# Epoch 16/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 86s 6s/step - accuracy: 0.9510 - loss: 0.2676 - val_accuracy: 0.2167 - val_loss: 1.9706
# Epoch 17/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 76s 5s/step - accuracy: 0.9545 - loss: 0.2597 - val_accuracy: 0.1958 - val_loss: 2.1089
# Epoch 18/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 77s 5s/step - accuracy: 0.9633 - loss: 0.2358 - val_accuracy: 0.2292 - val_loss: 1.8008
# Epoch 19/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 369s 26s/step - accuracy: 0.9633 - loss: 0.2175 - val_accuracy: 0.2896 - val_loss: 1.7886
# Epoch 20/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 189s 10s/step - accuracy: 0.9816 - loss: 0.1857 - val_accuracy: 0.3667 - val_loss: 1.5767
# Epoch 21/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 58s 4s/step - accuracy: 0.9760 - loss: 0.1749 - val_accuracy: 0.3625 - val_loss: 1.6322
# Epoch 22/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9707 - loss: 0.1690 - val_accuracy: 0.4292 - val_loss: 1.5369
# Epoch 23/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9806 - loss: 0.1597 - val_accuracy: 0.5938 - val_loss: 1.1123
# Epoch 24/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.9858 - loss: 0.1380 - val_accuracy: 0.6667 - val_loss: 0.9122
# Epoch 25/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.9865 - loss: 0.1216 - val_accuracy: 0.5875 - val_loss: 1.1487
# Epoch 26/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.9863 - loss: 0.1292 - val_accuracy: 0.6313 - val_loss: 0.9749
# Epoch 27/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 58s 4s/step - accuracy: 0.9849 - loss: 0.1283 - val_accuracy: 0.7000 - val_loss: 0.8144
# Epoch 28/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 80s 4s/step - accuracy: 0.9937 - loss: 0.1115 - val_accuracy: 0.6875 - val_loss: 0.8275
# Epoch 29/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.9916 - loss: 0.0993 - val_accuracy: 0.6938 - val_loss: 0.8498
# Epoch 30/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.9896 - loss: 0.0972 - val_accuracy: 0.6938 - val_loss: 0.8789
# Epoch 31/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.9856 - loss: 0.0977 - val_accuracy: 0.7188 - val_loss: 0.8141
# Epoch 32/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.9920 - loss: 0.0839 - val_accuracy: 0.6917 - val_loss: 0.8873
# Epoch 33/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9943 - loss: 0.0822 - val_accuracy: 0.6333 - val_loss: 1.1104
# Epoch 34/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.9906 - loss: 0.0866 - val_accuracy: 0.7333 - val_loss: 0.8105
# Epoch 35/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9929 - loss: 0.0870 - val_accuracy: 0.7167 - val_loss: 0.7811
# Epoch 36/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9874 - loss: 0.0858 - val_accuracy: 0.7167 - val_loss: 0.9200
# Epoch 37/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9962 - loss: 0.0716 - val_accuracy: 0.7437 - val_loss: 0.7769
# Epoch 38/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9961 - loss: 0.0646 - val_accuracy: 0.7208 - val_loss: 0.8726
# Epoch 39/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.9974 - loss: 0.0620 - val_accuracy: 0.7312 - val_loss: 0.8126
# Epoch 40/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9975 - loss: 0.0539 - val_accuracy: 0.7375 - val_loss: 0.7508
# Epoch 41/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.9985 - loss: 0.0528 - val_accuracy: 0.7188 - val_loss: 0.7964
# Epoch 42/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.9986 - loss: 0.0551 - val_accuracy: 0.7271 - val_loss: 0.8308
# Epoch 43/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 58s 4s/step - accuracy: 0.9989 - loss: 0.0545 - val_accuracy: 0.7250 - val_loss: 0.8004
# Epoch 44/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 62s 4s/step - accuracy: 1.0000 - loss: 0.0497 - val_accuracy: 0.7250 - val_loss: 0.8363
# Epoch 45/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.9993 - loss: 0.0428 - val_accuracy: 0.7375 - val_loss: 0.8096
# Epoch 46/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.9994 - loss: 0.0424 - val_accuracy: 0.7312 - val_loss: 0.9557
# Epoch 47/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9994 - loss: 0.0412 - val_accuracy: 0.7417 - val_loss: 0.7629
# Epoch 48/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9996 - loss: 0.0404 - val_accuracy: 0.7146 - val_loss: 1.0145
# Epoch 49/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9973 - loss: 0.0470 - val_accuracy: 0.7188 - val_loss: 0.9502
# Epoch 50/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.9987 - loss: 0.0399 - val_accuracy: 0.7063 - val_loss: 0.8603
# Epoch 51/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9972 - loss: 0.0388 - val_accuracy: 0.7479 - val_loss: 0.7580
# Epoch 52/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.9989 - loss: 0.0441 - val_accuracy: 0.7271 - val_loss: 0.8720
# Epoch 53/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.9987 - loss: 0.0386 - val_accuracy: 0.7333 - val_loss: 0.8367
# Epoch 54/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 84s 4s/step - accuracy: 0.9975 - loss: 0.0373 - val_accuracy: 0.7104 - val_loss: 0.9223
# Epoch 55/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9991 - loss: 0.0338 - val_accuracy: 0.6667 - val_loss: 1.0980
# Epoch 56/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.9986 - loss: 0.0332 - val_accuracy: 0.7271 - val_loss: 0.8651
# Epoch 57/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9997 - loss: 0.0325 - val_accuracy: 0.7417 - val_loss: 0.8505
# Epoch 58/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9992 - loss: 0.0349 - val_accuracy: 0.7271 - val_loss: 0.8384
# Epoch 59/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.9993 - loss: 0.0316 - val_accuracy: 0.7583 - val_loss: 0.8395
# Epoch 60/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 1.0000 - loss: 0.0301 - val_accuracy: 0.7417 - val_loss: 0.8700
# Epoch 61/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.9993 - loss: 0.0316 - val_accuracy: 0.7292 - val_loss: 0.8576
# Epoch 62/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.9991 - loss: 0.0294 - val_accuracy: 0.7625 - val_loss: 0.8521
# Epoch 63/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.9961 - loss: 0.0277 - val_accuracy: 0.7188 - val_loss: 0.8844
# Epoch 64/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 54s 4s/step - accuracy: 0.9994 - loss: 0.0265 - val_accuracy: 0.7542 - val_loss: 0.8805
# Epoch 65/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.9994 - loss: 0.0226 - val_accuracy: 0.7458 - val_loss: 0.8279
# Epoch 66/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.9999 - loss: 0.0240 - val_accuracy: 0.7354 - val_loss: 0.9671
# Epoch 67/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 54s 4s/step - accuracy: 0.9984 - loss: 0.0260 - val_accuracy: 0.7479 - val_loss: 0.8094
# Epoch 68/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.9986 - loss: 0.0277 - val_accuracy: 0.7396 - val_loss: 0.9119
# Epoch 69/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.9991 - loss: 0.0223 - val_accuracy: 0.7250 - val_loss: 0.9262
# Epoch 70/70
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 97s 7s/step - accuracy: 0.9995 - loss: 0.0220 - val_accuracy: 0.7354 - val_loss: 0.9035

# %%
# Saving model
model.save("intel_image.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
# Calculating test accuracy 
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.7695 - loss: 0.8482
# Test Accuracy: 76.99999809265137

# %%
# Storing model predictions
y_pred = model.predict(x_test)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step

# %%
# Plotting image to compare
img = array_to_img(x_test[1])

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[1])])
print("Predicted : ",labels[np.argmax(y_pred[1])])
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']
# Originally :  buildings
# Predicted :  buildings
